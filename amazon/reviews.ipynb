# %%
# ! pip install --user pandas
# ! pip install Jinja2 --user pandas
# ! pip install currencyconverter --user pandas
# ! pip install matplotlib --user pandas
# ! pip install textblob --user pandas
import pandas as pd
from textblob import TextBlob

# %%
df1 = pd.read_csv('./data/dados_Imersão - dados.csv')
df2 = pd.read_csv('./data/Avaliacoes.csv')
df = pd.merge(df1, df2, on=['product_id'], how='left')

df.head()
# Out:
#    product_id                                       product_name  \
# 0  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 2  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 3  B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 4  B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
#
#                                             category actual_price  \
# 0  Computers&Accessories|Accessories&Peripherals|...      ₹399,00
# 1  Computers&Accessories|Accessories&Peripherals|...      ₹399,00
# 2  Computers&Accessories|Accessories&Peripherals|...      ₹399,00
# 3  Computers&Accessories|Accessories&Peripherals|...      ₹199,00
# 4  Computers&Accessories|Accessories&Peripherals|...      ₹199,00
#
#   product_price rating  rating_count  \
# 0     ₹1.099,00    4,5         24269
# 1     ₹1.099,00    4,5         24269
# 2     ₹1.099,00    4,5         24269
# 3       ₹349,00      4         43994
# 4       ₹349,00      4         43994
#
#                                        about_product  \
# 0  High Compatibility : Compatible With iPhone 12...
# 1  High Compatibility : Compatible With iPhone 12...
# 2  High Compatibility : Compatible With iPhone 12...
# 3  Compatible with all Type C enabled devices, be...
# 4  Compatible with all Type C enabled devices, be...
#
#                                         product_link  \
# 0  https://www.amazon.in/Wayona-Braided-WN3LG1-Sy...
# 1  https://www.amazon.in/Wayona-Braided-WN3LG1-Sy...
# 2  https://www.amazon.in/Wayona-Braided-WN3LG1-Sy...
# 3  https://www.amazon.in/Ambrane-Unbreakable-Char...
# 4  https://www.amazon.in/Ambrane-Unbreakable-Char...
#
#                                              user_id  \
# 0  AG3D6O4STAQKAY2UVGEUV46KN35Q,AHMY5CWJMMK5BJRBB...
# 1  AG3D6O4STAQKAY2UVGEUV46KN35Q,AHMY5CWJMMK5BJRBB...
# 2  AG3D6O4STAQKAY2UVGEUV46KN35Q,AHMY5CWJMMK5BJRBB...
# 3  AECPFYFQVRUWC3KGNLJIOREFP5LQ,AGYYVPDD7YG7FYNBX...
# 4  AECPFYFQVRUWC3KGNLJIOREFP5LQ,AGYYVPDD7YG7FYNBX...
#
#                                            user_name  \
# 0  Manav,Adarsh gupta,Sundeep,S.Sayeed Ahmed,jasp...
# 1  Manav,Adarsh gupta,Sundeep,S.Sayeed Ahmed,jasp...
# 2  Manav,Adarsh gupta,Sundeep,S.Sayeed Ahmed,jasp...
# 3  ArdKn,Nirbhay kumar,Sagar Viswanathan,Asp,Plac...
# 4  ArdKn,Nirbhay kumar,Sagar Viswanathan,Asp,Plac...
#
#                                            review_id  \
# 0  R3HXWT0LRP0NMF,R2AJM3LFTLZHFO,R6AQJGUP6P86,R1K...
# 1  R3HXWT0LRP0NMF,R2AJM3LFTLZHFO,R6AQJGUP6P86,R1K...
# 2  R3HXWT0LRP0NMF,R2AJM3LFTLZHFO,R6AQJGUP6P86,R1K...
# 3  RGIQEG07R9HS2,R1SMWZQ86XIN8U,R2J3Y1WL29GWDE,RY...
# 4  RGIQEG07R9HS2,R1SMWZQ86XIN8U,R2J3Y1WL29GWDE,RY...
#
#                                         review_title  \
# 0  Satisfied,Charging is really fast,Value for mo...
# 1  Satisfied,Charging is really fast,Value for mo...
# 2  Satisfied,Charging is really fast,Value for mo...
# 3  A Good Braided Cable for Your Type C Device,Go...
# 4  A Good Braided Cable for Your Type C Device,Go...
#
#                                       review_content  \
# 0  Looks durable Charging is fine tooNo complains...
# 1  Looks durable Charging is fine tooNo complains...
# 2  Looks durable Charging is fine tooNo complains...
# 3  I ordered this cable to connect my phone to An...
# 4  I ordered this cable to connect my phone to An...
#
#                                             img_link
# 0  https://m.media-amazon.com/images/W/WEBP_40237...
# 1  https://m.media-amazon.com/images/I/51UsScvHQN...
# 2  https://m.media-amazon.com/images/W/WEBP_40237...
# 3  https://m.media-amazon.com/images/W/WEBP_40237...
# 4  https://m.media-amazon.com/images/I/31zOsqQOAO...

# %%
# tratando dados
df['product_price'] = df['product_price'].str.replace('₹', '').str.replace('.', '').str.replace(',', '.')
df['product_price'] = df['product_price'].astype(float)

df['actual_price'] = df['actual_price'].str.replace('₹', '').str.replace('.', '').str.replace(',', '.')
df['actual_price'] = df['actual_price'].astype(float)

df['rating'] = df['rating'].str.replace(',', '.')
df['rating'] = df['rating'].astype(float)

df.head()
# Out:
# C:\Users\mrxca\AppData\Local\Temp\ipykernel_16452\3952485639.py:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['product_price'] = df['product_price'].str.replace('₹', '').str.replace('.', '').str.replace(',', '.')
# C:\Users\mrxca\AppData\Local\Temp\ipykernel_16452\3952485639.py:5: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['actual_price'] = df['actual_price'].str.replace('₹', '').str.replace('.', '').str.replace(',', '.')
#    product_id                                       product_name  \
# 0  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 2  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 3  B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 4  B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
#
#                                             category  actual_price  \
# 0  Computers&Accessories|Accessories&Peripherals|...         399.0
# 1  Computers&Accessories|Accessories&Peripherals|...         399.0
# 2  Computers&Accessories|Accessories&Peripherals|...         399.0
# 3  Computers&Accessories|Accessories&Peripherals|...         199.0
# 4  Computers&Accessories|Accessories&Peripherals|...         199.0
#
#    product_price  rating  rating_count  \
# 0         1099.0     4.5         24269
# 1         1099.0     4.5         24269
# 2         1099.0     4.5         24269
# 3          349.0     4.0         43994
# 4          349.0     4.0         43994
#
#                                        about_product  \
# 0  High Compatibility : Compatible With iPhone 12...
# 1  High Compatibility : Compatible With iPhone 12...
# 2  High Compatibility : Compatible With iPhone 12...
# 3  Compatible with all Type C enabled devices, be...
# 4  Compatible with all Type C enabled devices, be...
#
#                                         product_link  \
# 0  https://www.amazon.in/Wayona-Braided-WN3LG1-Sy...
# 1  https://www.amazon.in/Wayona-Braided-WN3LG1-Sy...
# 2  https://www.amazon.in/Wayona-Braided-WN3LG1-Sy...
# 3  https://www.amazon.in/Ambrane-Unbreakable-Char...
# 4  https://www.amazon.in/Ambrane-Unbreakable-Char...
#
#                                              user_id  \
# 0  AG3D6O4STAQKAY2UVGEUV46KN35Q,AHMY5CWJMMK5BJRBB...
# 1  AG3D6O4STAQKAY2UVGEUV46KN35Q,AHMY5CWJMMK5BJRBB...
# 2  AG3D6O4STAQKAY2UVGEUV46KN35Q,AHMY5CWJMMK5BJRBB...
# 3  AECPFYFQVRUWC3KGNLJIOREFP5LQ,AGYYVPDD7YG7FYNBX...
# 4  AECPFYFQVRUWC3KGNLJIOREFP5LQ,AGYYVPDD7YG7FYNBX...
#
#                                            user_name  \
# 0  Manav,Adarsh gupta,Sundeep,S.Sayeed Ahmed,jasp...
# 1  Manav,Adarsh gupta,Sundeep,S.Sayeed Ahmed,jasp...
# 2  Manav,Adarsh gupta,Sundeep,S.Sayeed Ahmed,jasp...
# 3  ArdKn,Nirbhay kumar,Sagar Viswanathan,Asp,Plac...
# 4  ArdKn,Nirbhay kumar,Sagar Viswanathan,Asp,Plac...
#
#                                            review_id  \
# 0  R3HXWT0LRP0NMF,R2AJM3LFTLZHFO,R6AQJGUP6P86,R1K...
# 1  R3HXWT0LRP0NMF,R2AJM3LFTLZHFO,R6AQJGUP6P86,R1K...
# 2  R3HXWT0LRP0NMF,R2AJM3LFTLZHFO,R6AQJGUP6P86,R1K...
# 3  RGIQEG07R9HS2,R1SMWZQ86XIN8U,R2J3Y1WL29GWDE,RY...
# 4  RGIQEG07R9HS2,R1SMWZQ86XIN8U,R2J3Y1WL29GWDE,RY...
#
#                                         review_title  \
# 0  Satisfied,Charging is really fast,Value for mo...
# 1  Satisfied,Charging is really fast,Value for mo...
# 2  Satisfied,Charging is really fast,Value for mo...
# 3  A Good Braided Cable for Your Type C Device,Go...
# 4  A Good Braided Cable for Your Type C Device,Go...
#
#                                       review_content  \
# 0  Looks durable Charging is fine tooNo complains...
# 1  Looks durable Charging is fine tooNo complains...
# 2  Looks durable Charging is fine tooNo complains...
# 3  I ordered this cable to connect my phone to An...
# 4  I ordered this cable to connect my phone to An...
#
#                                             img_link
# 0  https://m.media-amazon.com/images/W/WEBP_40237...
# 1  https://m.media-amazon.com/images/I/51UsScvHQN...
# 2  https://m.media-amazon.com/images/W/WEBP_40237...
# 3  https://m.media-amazon.com/images/W/WEBP_40237...
# 4  https://m.media-amazon.com/images/I/31zOsqQOAO...

# %%
quantidade_registros = len(df)
print("Registros ", quantidade_registros)
print("colunas:",df.shape[1])
# Out:
# Registros  1737
# colunas: 15

# %% [markdown]
# # análise de satisfação

# %%
def analisar_sentimento(texto):
    analysis = TextBlob(texto)        
    if analysis.sentiment.polarity > 0:
        return 'Positivo'
    elif analysis.sentiment.polarity < 0:
        return 'Negativo'
    else:
        return 'Neutro'
    
def analisar_sentimento_polarity(texto):
    analysis = TextBlob(texto)    
    return analysis.sentiment.polarity    

def traduzir_para_portugues(titulo):
    blob = TextBlob(str(titulo))
    titulo_traduzido = str(blob.translate(to='pt'))
    return titulo_traduzido

df['review_title_pt'] = df['review_title'].apply(traduzir_para_portugues)


df['sentimento'] = df['review_content'].apply(analisar_sentimento)
df['sentimento_polarity'] = df['review_content'].apply(analisar_sentimento_polarity)



# df['review_title_pt'] = df['review_title'].apply(traduzir_para_portugues)

df.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 19
#      16     titulo_traduzido = str(blob.translate(to='pt'))
#      17     return titulo_traduzido
# ---> 19 df['review_title_pt'] = df['review_title'].apply(traduzir_para_portugues)
#      22 df['sentimento'] = df['review_content'].apply(analisar_sentimento)
#      23 df['sentimento_polarity'] = df['review_content'].apply(analisar_sentimento_polarity)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\core\series.py:4774, in Series.apply(self, func, convert_dtype, args, **kwargs)
#    4664 def apply(
#    4665     self,
#    4666     func: AggFuncType,
#    (...)
#    4669     **kwargs,
#    4670 ) -> DataFrame | Series:
#    4671     """
#    4672     Invoke function on values of Series.
#    4673
#    (...)
#    4772     dtype: float64
#    4773     """
# -> 4774     return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\core\apply.py:1100, in SeriesApply.apply(self)
#    1097     return self.apply_str()
#    1099 # self.f is Callable
# -> 1100 return self.apply_standard()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\core\apply.py:1151, in SeriesApply.apply_standard(self)
#    1149     else:
#    1150         values = obj.astype(object)._values
# -> 1151         mapped = lib.map_infer(
#    1152             values,
#    1153             f,
#    1154             convert=self.convert_dtype,
#    1155         )
#    1157 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1158     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1159     #  See also GH#25959 regarding EA support
#    1160     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\_libs\lib.pyx:2919, in pandas._libs.lib.map_infer()
#
# Cell In[6], line 16, in traduzir_para_portugues(titulo)
#      14 def traduzir_para_portugues(titulo):
#      15     blob = TextBlob(str(titulo))
# ---> 16     titulo_traduzido = str(blob.translate(to='pt'))
#      17     return titulo_traduzido
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\textblob\blob.py:568, in BaseBlob.translate(self, from_lang, to)
#     539 """Translate the blob to another language.
#     540 Uses the Google Translate API. Returns a new TextBlob.
#     541
#    (...)
#     561 :rtype: :class:`BaseBlob <BaseBlob>`
#     562 """
#     563 warnings.warn(
#     564     'TextBlob.translate is deprecated and will be removed in a future release. '
#     565     'Use the official Google Translate API instead.',
#     566     DeprecationWarning
#     567 )
# --> 568 return self.__class__(self.translator.translate(self.raw,
#     569                       from_lang=from_lang, to_lang=to))
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\textblob\translate.py:61, in Translator.translate(self, source, from_lang, to_lang, host, type_)
#      59     except IndexError:
#      60         pass
# ---> 61 self._validate_translation(source, result)
#      62 return result
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\textblob\translate.py:88, in Translator._validate_translation(self, source, result)
#      86 if PY2:
#      87     result = result.encode('utf-8')
# ---> 88 if result.strip() == source.strip():
#      89     raise NotTranslated('Translation API returned the input string unchanged.')
#
# AttributeError: 'list' object has no attribute 'strip'

# %%
contagem_sentimento = df['sentimento'].value_counts()
contagem_sentimento = contagem_sentimento.sort_index(ascending=True)
contagem_sentimento
# Out:
# Negativo      28
# Neutro         1
# Positivo    1708
# Name: sentimento, dtype: int64
